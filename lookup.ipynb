# %%
import pandas as pd

# %%
pd.options.display.max_columns = None

# %%
df = pd.read_csv("swan_data.csv")

# %%
df[df.CustomerID == '5150-ITWWB']
# Out:
#       CustomerID  Count        Country       State           City  Zip Code  \
# 4198  5150-ITWWB      1  United States  California  Hamilton City     95951
#
#                     Lat Long   Latitude   Longitude Gender Senior Citizen  \
# 4198  39.732767, -122.042298  39.732767 -122.042298   Male            Yes
#
#      Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# 4198      No         No              3           Yes            Yes
#
#      Internet Service Online Security Online Backup Device Protection  \
# 4198      Fiber optic              No            No                No
#
#      Tech Support Streaming TV Streaming Movies        Contract  \
# 4198           No          Yes              Yes  Month-to-month
#
#      Paperless Billing    Payment Method  Monthly Charges Total Charges  \
# 4198               Yes  Electronic check            94.85        335.75
#
#      Churn Label  Churn Value Churn Reason
# 4198          No            0          NaN

# %%
with open("SumYe_Logistic_Regression/most_likely_churners.txt", "r") as churners:
    for line in churners:
        line = line.strip()
        print(line)
# Out:
# 0187-QSXOE
# 5150-ITWWB
# 6350-XFYGW
# 7577-SWIFR
# 6630-UJZMY
# 4847-TAJYI
# 3318-NMQXL
# 4115-NZRKS
# 4927-WWOOZ
# 3489-HHPFY
# 7668-XCFYV
# 8161-QYMTT
# 2545-EBUPK
# 7225-CBZPL
# 7398-SKNQZ
# 3452-GWUIN
# 7363-QTBIW
# 6583-KQJLK
# 9799-CAYJJ
# 9290-SHCMB
# 8622-ZLFKO
# 4912-PIGUY
# 8087-LGYHQ
# 7439-DKZTW
# 4929-XIHVW
# 2880-FPNAE
# 3096-GKWEB
# 0480-BIXDE
# 7321-VGNKU
# 9402-ORRAH
# 1393-IMKZG
# 2789-HQBOU
# 6357-JJPQT
# 3320-VEOYC
# 4234-XTNEA
# 7044-YAACC
# 1628-BIZYP
# 6507-ZJSUR
# 2123-AGEEN
# 9919-KNPOO
# 2799-ARNLO
# 0365-BZUWY
# 5935-FCCNB
# 6229-LSCKB
# 8739-XNIKG
# 4395-PZMSN
# 8242-SOQUO
# 6986-IXNDM
# 9605-WGJVW
# 3317-VLGQT
# 0018-NYROU
# 2077-MPJQO
# 3878-AVSOQ
# 0021-IKXGC
# 9957-YODKZ
# 9334-GWGOW
# 6969-MVBAI
# 2688-BHGOG
# 0722-SVSFK
# 9603-OAIHC
# 4884-ZTHVF
# 2371-JQHZZ
# 3629-ZNKXA
# 3462-BJQQA
# 5995-SNNEW
# 9094-AZPHK
# 1640-PLFMP
# 7394-LWLYN
# 5542-TBBWB
# 2984-AFWNC
# 2081-VEYEH
# 5288-AHOUP
# 1197-BVMVG
# 7465-ZZRVX
# 7858-GTZSP
# 4482-EWFMI
# ...
